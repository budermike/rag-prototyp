# %% [markdown]
# # RAG Prototyp

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt

import torch
import ollama
import qdrant

# %%
# Import Dataset
dataset = []
with open("./data/duck_facts.txt", "r") as file:
    dataset = file.readlines()
    print(f'Loaded {len(dataset)} entries')
# Out:
# Loaded 133 entries

# %%
# Load Models
EMBEDDING_MODEL = "qwen3-embedding:0.6b"
LANGUAGE_MODEL = "qwen3.5:4b"

# %%
# Vector DB
vectorDB = []

# %%
# Retrievel Function
def cosine_similarity(vec1, vec2):
    pass


def retrieve():
    pass

# %%
# Generate Response
